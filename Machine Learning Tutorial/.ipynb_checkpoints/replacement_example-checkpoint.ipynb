# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# ***

# %% [markdown]
# ## RANdom SAmple Consensus (RANSAC) Algorithm
#
# using simple algorithm, can be improved with advance methods that control the loss function i.e. Huber loss, etc..
#
#  > link to RANSAC = [http://scikit-learn.org/stable/modules/linear_model.html#ransac-regression](http://scikit-learn.org/stable/modules/linear_model.html#ransac-regression)

# %% [markdown]
# Each iteration performs the following steps:
#
# 1. Select `min_samples` random samples from the original data and check whether the set of data is valid (see `is_data_valid`).
#
# 2. Fit a model to the random subset (`base_estimator.fit`) and check whether the estimated model is valid (see `is_model_valid`).
#
# 3. Classify all data as inliers or outliers by calculating the residuals to the estimated model (`base_estimator.predict(X) - y`) - all data samples with absolute residuals smaller than the `residual_threshold` are considered as inliers.
#
# 4. Save fitted model as best model if number of inlier samples is maximal. In case the current estimated model has the same number of inliers, it is only considered as the best model if it has better score.

# %% [markdown]
# ### Example: Predicting dividends yield

# %%
def unpickle_me(filename):
    with open(filename, 'rb') as fh:
        return pickle.load(fh)
    
instruments = unpickle_me('../data/instruments.p')
instruments = pd.concat([instruments['symbol'], instruments.select_dtypes(['float64'])], axis=1)

# %%
instruments.head()
# Out:
#   symbol  price     open     high      low  high_52_weeks  low_52_weeks  \
# 0   ROBT    NaN  29.4600  29.4711  29.1700        31.5700        28.081
# 1   TMFC    NaN  19.2964  19.3200  19.0900        20.2324        17.800
# 2   LEGR    NaN  29.1200  29.1390  28.9000        30.7500        26.801
# 3   BLOK    NaN  19.2900  19.3600  19.1553        21.4590        17.921
# 4   BLCN    NaN  22.7400  22.7400  22.6000        25.0500        21.690
#
#    percent_off_52_week_high   volume  average_volume      ...        \
# 0                       NaN   4326.0      19449.7073      ...
# 1                       NaN  21893.0     170078.5789      ...
# 2                       NaN  14410.0      34676.1333      ...
# 3                       NaN  45327.0     429249.7576      ...
# 4                       NaN  16718.0     202369.5000      ...
#
#    num_buy_ratings  num_hold_ratings  num_sell_ratings  percent_buy_ratings  \
# 0              NaN               NaN               NaN                  NaN
# 1              NaN               NaN               NaN                  NaN
# 2              NaN               NaN               NaN                  NaN
# 3              NaN               NaN               NaN                  NaN
# 4              NaN               NaN               NaN                  NaN
#
#    percent_sell_ratings  day_trade_ratio  maintenance_ratio  \
# 0                   NaN             0.25               0.45
# 1                   NaN             0.25               0.60
# 2                   NaN             0.25               0.25
# 3                   NaN             0.25               0.60
# 4                   NaN             0.25               0.60
#
#    margin_initial_ratio  pe_ratio  min_tick_size
# 0                  0.56   77.3704            NaN
# 1                  0.68   26.8527            NaN
# 2                  0.50   26.5330            NaN
# 3                  0.68   39.6359            NaN
# 4                  0.68   28.1871            NaN
#
# [5 rows x 30 columns]

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

dependent_var = 'div_yield'
independent_var = 'percent_buy_ratings'

regress_df = pd.concat([instruments[independent_var], instruments[dependent_var]], axis=1)
regress_df - clean_dataset(regress_df)
regress_df.head()
# Out:
#     percent_buy_ratings  div_yield
# 40             0.793103       2.32
# 50             0.461538       0.97
# 54             0.866667       1.69
# 70             0.400000       0.84
# 78             0.650000       0.69

# %%
X = regress_df[independent_var].values.reshape(-1,1)
y = regress_df[dependent_var].astype(np.float64)

# %%
from sklearn.linear_model import RANSACRegressor

ransac = RANSACRegressor()
ransac.fit(X, y)

inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

# %%
line_X = np.arange(0, 1.3, 0.1)
line_y_ransac = ransac.predict(line_X.reshape(-1, 1))

# %%
import seaborn as sns

sns.set(style='whitegrid', context='notebook')
plt.figure(figsize=(12,10));
plt.scatter(X[inlier_mask], y[inlier_mask], 
            c='blue', marker='o', label='Inliers')
plt.scatter(X[outlier_mask], y[outlier_mask],
            c='brown', marker='s', label='Outliers')
plt.plot(line_X, line_y_ransac, color='red')
plt.xlim(0,1.5)
plt.ylim(-2, 7)
plt.xlabel(independent_var)
plt.ylabel(dependent_var)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # 5: Correlation Analysis and Feature Selection

# %%
pd.options.display.float_format = '{:,.2f}'.format
focus_columns = [ 'div_yield', 'div_growth', \
       'annual_payout', 'payout_ratio', 'num_employees', 'year_founded', \
       'shares_outstanding', 'market_cap', 'num_buy_ratings', \
       'num_hold_ratings', 'num_sell_ratings', 'percent_buy_ratings', \
       'percent_sell_ratings']

instruments = instruments[focus_columns]
instruments.corr()
# Out:
#                       div_yield  div_growth  annual_payout  payout_ratio  \
# div_yield                  1.00       -0.18           0.68          0.66
# div_growth                -0.18        1.00           0.33         -0.19
# annual_payout              0.68        0.33           1.00          0.05
# payout_ratio               0.66       -0.19           0.05          1.00
# num_employees             -0.12        0.07           0.03         -0.17
# year_founded               0.04       -0.03          -0.15         -0.02
# shares_outstanding        -0.01       -0.02           0.08         -0.06
# market_cap                 0.06        0.32           0.38         -0.07
# num_buy_ratings            0.01        0.27           0.62          0.10
# num_hold_ratings           0.02       -0.22          -0.23         -0.09
# num_sell_ratings          -0.02       -0.31          -0.12          0.05
# percent_buy_ratings       -0.08        0.25           0.33          0.05
# percent_sell_ratings       0.06       -0.31          -0.08          0.09
#
#                       num_employees  year_founded  shares_outstanding  \
# div_yield                     -0.12          0.04               -0.01
# div_growth                     0.07         -0.03               -0.02
# annual_payout                  0.03         -0.15                0.08
# payout_ratio                  -0.17         -0.02               -0.06
# num_employees                  1.00         -0.09                0.33
# year_founded                  -0.09          1.00               -0.11
# shares_outstanding             0.33         -0.11                1.00
# market_cap                     0.43         -0.16                0.61
# num_buy_ratings                0.27         -0.04                0.31
# num_hold_ratings               0.21         -0.21                0.20
# num_sell_ratings               0.06         -0.14                0.24
# percent_buy_ratings            0.08          0.09                0.06
# percent_sell_ratings          -0.03         -0.08                0.08
#
#                       market_cap  num_buy_ratings  num_hold_ratings  \
# div_yield                   0.06             0.01              0.02
# div_growth                  0.32             0.27             -0.22
# annual_payout               0.38             0.62             -0.23
# payout_ratio               -0.07             0.10             -0.09
# num_employees               0.43             0.27              0.21
# year_founded               -0.16            -0.04             -0.21
# shares_outstanding          0.61             0.31              0.20
# market_cap                  1.00             0.46              0.25
# num_buy_ratings             0.46             1.00              0.06
# num_hold_ratings            0.25             0.06              1.00
# num_sell_ratings            0.08            -0.07              0.37
# percent_buy_ratings         0.14             0.66             -0.52
# percent_sell_ratings       -0.04            -0.29              0.13
#
#                       num_sell_ratings  percent_buy_ratings  \
# div_yield                        -0.02                -0.08
# div_growth                       -0.31                 0.25
# annual_payout                    -0.12                 0.33
# payout_ratio                      0.05                 0.05
# num_employees                     0.06                 0.08
# year_founded                     -0.14                 0.09
# shares_outstanding                0.24                 0.06
# market_cap                        0.08                 0.14
# num_buy_ratings                  -0.07                 0.66
# num_hold_ratings                  0.37                -0.52
# num_sell_ratings                  1.00                -0.38
# percent_buy_ratings              -0.38                 1.00
# percent_sell_ratings              0.80                -0.49
#
#                       percent_sell_ratings
# div_yield                             0.06
# div_growth                           -0.31
# annual_payout                        -0.08
# payout_ratio                          0.09
# num_employees                        -0.03
# year_founded                         -0.08
# shares_outstanding                    0.08
# market_cap                           -0.04
# num_buy_ratings                      -0.29
# num_hold_ratings                      0.13
# num_sell_ratings                      0.80
# percent_buy_ratings                  -0.49
# percent_sell_ratings                  1.00

# %%
corr_matrix = instruments.corr() 
corr_matrix[np.abs(corr_matrix) < 0.6] = 0

plt.figure(figsize=(16,10))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# ## Statsmodel

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf


#We need to add a constant term to allow statsmodel.api to calculate the bias / intercepts.
X_constant = sm.add_constant(X)
# Out:
# c:\users\salimn.middleeast\appdata\local\conda\conda\envs\udemy\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
stats_model = sm.OLS(y, X_constant)
stats_lr = stats_model.fit()

# %%
stats_lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              div_yield   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.026
# Method:                 Least Squares   F-statistic:                    0.1876
# Date:                Mon, 21 May 2018   Prob (F-statistic):              0.668
# Time:                        19:54:19   Log-Likelihood:                -59.509
# No. Observations:                  33   AIC:                             123.0
# Df Residuals:                      31   BIC:                             126.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5154      0.911      2.760      0.010       0.657       4.374
# x1            -0.6266      1.447     -0.433      0.668      -3.577       2.324
# ==============================================================================
# Omnibus:                        9.186   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                8.098
# Skew:                           1.170   Prob(JB):                       0.0174
# Kurtosis:                       3.640   Cond. No.                         7.53
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# There are a lot of statistical tests and information. Mostly for the purpose of statistical analysis.
#
# You do not need all of these for data science.
#
# Data science focus is on prediction and having models that work on predicting real data. It is not concerned as much with  correct specifications of statistical problems.

# %% [markdown]
# ## Detecting Collinearity with Eigenvectors

# %%
eigenvalues, eigenvectors = np.linalg.eig(instruments.corr())

# %%
pd.Series(eigenvalues).sort_values().plot.bar(figsize=(15,4))

# %% [markdown]
#  > Note that index 4, is near to zero or very small compared to the others. **Small value represents presence of collinearity**

# %%
focus_index = np.abs(pd.Series(eigenvectors[:,4])).sort_values(ascending=False)
focus_index.plot.bar(figsize=(15,4))

# %% [markdown]
#  > Note that column index 11, 12, 9 have very high loading when compared against the rest

# %%
print('Columns causing multicolinearity: {}'.format( \
    [focus_columns[i] for i in range(len(focus_index[:3].index)) ]))
# Out:
# Columns causing multicolinearity: ['div_yield', 'div_growth', 'annual_payout']
